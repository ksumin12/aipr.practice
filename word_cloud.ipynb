# %%
pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp39-cp39-win_amd64.whl (153 kB)
# Collecting numpy>=1.6.1
#   Downloading numpy-1.26.0-cp39-cp39-win_amd64.whl (15.8 MB)
# Collecting matplotlib
#   Downloading matplotlib-3.8.0-cp39-cp39-win_amd64.whl (7.6 MB)
# Collecting pillow
#   Downloading Pillow-10.0.1-cp39-cp39-win_amd64.whl (2.5 MB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.42.1-cp39-cp39-win_amd64.whl (2.1 MB)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\temp\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (23.1)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp39-cp39-win_amd64.whl (435 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\temp\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\temp\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\temp\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: numpy, pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib, wordcloud
# Successfully installed contourpy-1.1.1 cycler-0.11.0 fonttools-4.42.1 importlib-resources-6.0.1 kiwisolver-1.4.5 matplotlib-3.8.0 numpy-1.26.0 pillow-10.0.1 pyparsing-3.1.1 wordcloud-1.9.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python39_64\python.exe -m pip install --upgrade pip' command.

# %%
pip install konlpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp39-cp39-win_amd64.whl (345 kB)
# Requirement already satisfied: numpy>=1.6 in c:\users\temp\appdata\roaming\python\python39\site-packages (from konlpy) (1.26.0)
# Collecting lxml>=4.1.0
#   Downloading lxml-4.9.3-cp39-cp39-win_amd64.whl (3.9 MB)
# Requirement already satisfied: packaging in c:\users\temp\appdata\roaming\python\python39\site-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: lxml, JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0 lxml-4.9.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python39_64\python.exe -m pip install --upgrade pip' command.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

with open('news.txt', 'r', encoding='utf-8') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) 

words = [n for n in nouns if len(n) > 1] 

c = Counter(words)

wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

wc.to_file('news_word_cloud.png')
